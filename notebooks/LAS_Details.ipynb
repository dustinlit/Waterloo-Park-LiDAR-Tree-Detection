# %%
import pandas as pd
import numpy as np
import laspy

# %%
cloud = laspy.read('data/clipped_point_cloud.las')

# %%
las.point_format.size

# %%
las.point_format

# %%
las.point_format.dimensions

# %%
las.point_format.extra_dimensions
